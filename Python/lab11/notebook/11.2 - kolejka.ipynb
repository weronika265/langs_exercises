# %% [markdown]
# [2 punkty]
#
# System kodowania miejsc w pociągu (system.jpg):
# - pierwsza część to numer przedziału (od 1 do 11),
# - miejsca przy oknie mają ostatnią cyfrę 5 i 6,
# - miejsca "od korytarza" mają ostatnią cyfrę 1 i 2,
# - miejsca środkowe w przedziałach sześcioosobowych mają ostatnią cyfrę 3 i 4,
# - w przedziałach ośmioosobowych są to dodatkowo miejsca 7 i 8
# - nieparzyste po lewej stronie od wejścia.
#
# Stąd też miejsce 35 znajduje się"
# - w 3 przedziale
# - przy oknie
# - po lewej stronie.
#
# Wprowadzono "ułatwienie", pozwalające szybko odszukać miejsce z pomocą drzewa binarnego.
# Na biletach wydrukowany jest ciąg 6 liter.
# Każda litera określa w której połówce w danym podziale znaduje się konkretne miejsce.
#
# Pierwsze 3 z nich mogą mieć wartości:
# - L - przód (niski numer)
# - H - tył (wysoki numer)
#
# Kolejna:
# - P - parzyste
# - N - nieparzyste
#
# Ostatnie 2 to:
# - O - okno
# - D - drzwi.
#
# Generowane są tylko poprawne kody.
#
# **Proszę napisać program, który okresli przedział i położenie fotela na podstawie podanego ciągu**. Dwuelementowa krotka, np. (2, 4)
#
# Przykład 1:
# ```
# print( pociag('LLHPOD') )
# (2, 4)
#
# ponieważ:
# LLH - P - OD
#
# LLH
# liczba przedziałów - 8 (2^3)
# pierwsza litera L: 1-4
# druga litera L: 1-2
# litera H: 2
#
# P - parzyste
#
# liczba miejsc - 4 w rzędzie (2^2)
# O - jedno z 2 miejsc bliżej okna
# D - miejsce drugie od okna
#
# miejsce w przedziale 2 numer 4
# ```
#
# Przykład 2:
# ```
# print( pociag('LHLNDO') )
# (3, 3)
# ```

# %%
przedzialy = [] # len
class Node:
    def __init__(self, data = None):
        self.left = None # *okno/ drzwi
        self.right = None # okno/ *drzwi
        self.data = data # L/ H
        
    def traverse_tree_przedzialy(self, root):
        if root == Node:
            return
        for i in przedzialy:
            if i == 'L':
                self.left
        
def add_node(self, root):
        pass
        
przedzialy = [] # len
parzystosc = 2
miejsca = [] # len      
def pociag(str):
#     przedzialy = [] # len
#     parzystosc = 0
#     miejsca = [] # len
    for l in str:
        if l in ['L', 'H']:
            przedzialy.append(l)
        elif l == 'P':
            parzystosc = 2
        elif l == 'N':
            parzystosc = 1
        elif l in ['O', 'D']:
            miejsca.append(l)
                 
# def traverse_tree_miejsca(self, root):
#         if root == Node:
#             return
#         if
        
# inorder traversal??
            
root_przedzial = Node()

root_przedzial.left = Node()
root_przedzial.left.left = Node()
root_przedzial.left.right = Node()
root_przedzial.left.left.left = Node(1)
root_przedzial.left.left.right = Node(2)
root_przedzial.left.right.left = Node(3)
root_przedzial.left.right.right = Node(4)

root_przedzial.right = Node()
root_przedzial.right.left = Node()
root_przedzial.right.right = Node()
root_przedzial.right.left.left = Node(5)
root_przedzial.right.left.right = Node(6)
root_przedzial.right.right.left = Node(7)
root_przedzial.right.right.right = Node(8)


root_miejsce = Node()
root_miejsce.left = Node()
root_miejsce.right = Node()
if parzystosc == 2:
    root_miejsce.left.left = Node(6)
    root_miejsce.left.right = Node(4)
    root_miejsce.right.left = Node(8)
    root_miejsce.right.right = Node(2)
elif parzystosc == 1:
    root_miejsce.left.left = Node(5)
    root_miejsce.left.right = Node(7)
    root_miejsce.right.left = Node(3)
    root_miejsce.right.right = Node(1)

# i = 1
# while i <= len(przedzialy):
#     # dodawaj kolejne Node'y bez wartości/ z 'L' lub 'H'
#     if i == len(przedzialy):
#         # dodawaj liczby przedzialow
#         pass

print(pociag('LHLNDO'))
# Out:
# None
