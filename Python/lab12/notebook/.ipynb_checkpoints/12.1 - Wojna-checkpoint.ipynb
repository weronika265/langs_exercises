# %% [markdown]
# Proszę napisać funkcję, która będzie symulować grę 2 graczy w wojnę.
# Przyjmować powinna 2 parametry:
# - listę kart pierwszego gracza,
# - listę kart drugiego gracza.
#
# Dla uproszczenia interesować nas będą tylko wartości kart, a nie kolor (zakres od 1 do ~~100000~~ bez limitu).
#
# W każdej turze gracze rzucają kartę z góry swojej ręki (pierwszą z listy) i porównują. Posiadający kartę silniejszą, bierze obie i odkłada na dół swojej ręki (tj. na koniec listy). Najpierw odkłada swoją, a później przeciwnika. W przypadku remisu, każdy z graczy odkłada swoją kartę na spód (na koniec listy).
#
# Gra toczy się, aż któryś z graczy pozbędzie się wszystkich kart.
#
# Proszę, aby funkcja wypisywała kolejne rundy (print) i zwracała (return) ile rund zostało rozegranych.
#
# ```
# print('rund rozgrywki:', wojna([1,4,6], [2,3,5]) )
#
# runda: 1
# ręka gracza 1: [1, 4, 6]
# ręka gracza 2: [2, 3, 5]
# gracz 1 rzuca: 1
# gracz 2 rzuca: 2
# pozostała ręka gracza 1: [4, 6]
# pozostała ręka gracza 2: [3, 5]
# wygrywa gracz: 2
#
# runda: 2
# ręka gracza 1: [4, 6]
# ręka gracza 2: [3, 5, 2, 1]
# gracz 1 rzuca: 4
# gracz 2 rzuca: 3
# pozostała ręka gracza 1: [6]
# pozostała ręka gracza 2: [5, 2, 1]
# wygrywa gracz: 1
#
# runda: 3
# ręka gracza 1: [6, 4, 3]
# ręka gracza 2: [5, 2, 1]
# gracz 1 rzuca: 6
# gracz 2 rzuca: 5
# pozostała ręka gracza 1: [4, 3]
# pozostała ręka gracza 2: [2, 1]
# wygrywa gracz: 1
#
# runda: 4
# ręka gracza 1: [4, 3, 6, 5]
# ręka gracza 2: [2, 1]
# gracz 1 rzuca: 4
# gracz 2 rzuca: 2
# pozostała ręka gracza 1: [3, 6, 5]
# pozostała ręka gracza 2: [1]
# wygrywa gracz: 1
#
# runda: 5
# ręka gracza 1: [3, 6, 5, 4, 2]
# ręka gracza 2: [1]
# gracz 1 rzuca: 3
# gracz 2 rzuca: 1
# pozostała ręka gracza 1: [6, 5, 4, 2]
# pozostała ręka gracza 2: []
# wygrywa gracz: 1
#
# rund rozgrywki: 5
# ```
#
# ```
# print('rund rozgrywki:', wojna([1,8,7,5], [2,4,3,6]) )
#
# runda: 1
# ręka gracza 1: [1, 8, 7, 5]
# ręka gracza 2: [2, 4, 3, 6]
# gracz 1 rzuca: 1
# gracz 2 rzuca: 2
# pozostała ręka gracza 1: [8, 7, 5]
# pozostała ręka gracza 2: [4, 3, 6]
# wygrywa gracz: 2
#
# runda: 2
# ręka gracza 1: [8, 7, 5]
# ręka gracza 2: [4, 3, 6, 2, 1]
# gracz 1 rzuca: 8
# gracz 2 rzuca: 4
# pozostała ręka gracza 1: [7, 5]
# pozostała ręka gracza 2: [3, 6, 2, 1]
# wygrywa gracz: 1
#
# runda: 3
# ręka gracza 1: [7, 5, 8, 4]
# ręka gracza 2: [3, 6, 2, 1]
# gracz 1 rzuca: 7
# gracz 2 rzuca: 3
# pozostała ręka gracza 1: [5, 8, 4]
# pozostała ręka gracza 2: [6, 2, 1]
# wygrywa gracz: 1
#
# runda: 4
# ręka gracza 1: [5, 8, 4, 7, 3]
# ręka gracza 2: [6, 2, 1]
# gracz 1 rzuca: 5
# gracz 2 rzuca: 6
# pozostała ręka gracza 1: [8, 4, 7, 3]
# pozostała ręka gracza 2: [2, 1]
# wygrywa gracz: 2
#
# runda: 5
# ręka gracza 1: [8, 4, 7, 3]
# ręka gracza 2: [2, 1, 6, 5]
# gracz 1 rzuca: 8
# gracz 2 rzuca: 2
# pozostała ręka gracza 1: [4, 7, 3]
# pozostała ręka gracza 2: [1, 6, 5]
# wygrywa gracz: 1
#
# runda: 6
# ręka gracza 1: [4, 7, 3, 8, 2]
# ręka gracza 2: [1, 6, 5]
# gracz 1 rzuca: 4
# gracz 2 rzuca: 1
# pozostała ręka gracza 1: [7, 3, 8, 2]
# pozostała ręka gracza 2: [6, 5]
# wygrywa gracz: 1
#
# runda: 7
# ręka gracza 1: [7, 3, 8, 2, 4, 1]
# ręka gracza 2: [6, 5]
# gracz 1 rzuca: 7
# gracz 2 rzuca: 6
# pozostała ręka gracza 1: [3, 8, 2, 4, 1]
# pozostała ręka gracza 2: [5]
# wygrywa gracz: 1
#
# runda: 8
# ręka gracza 1: [3, 8, 2, 4, 1, 7, 6]
# ręka gracza 2: [5]
# gracz 1 rzuca: 3
# gracz 2 rzuca: 5
# pozostała ręka gracza 1: [8, 2, 4, 1, 7, 6]
# pozostała ręka gracza 2: []
# wygrywa gracz: 2
#
# runda: 9
# ręka gracza 1: [8, 2, 4, 1, 7, 6]
# ręka gracza 2: [5, 3]
# gracz 1 rzuca: 8
# gracz 2 rzuca: 5
# pozostała ręka gracza 1: [2, 4, 1, 7, 6]
# pozostała ręka gracza 2: [3]
# wygrywa gracz: 1
#
# runda: 10
# ręka gracza 1: [2, 4, 1, 7, 6, 8, 5]
# ręka gracza 2: [3]
# gracz 1 rzuca: 2
# gracz 2 rzuca: 3
# pozostała ręka gracza 1: [4, 1, 7, 6, 8, 5]
# pozostała ręka gracza 2: []
# wygrywa gracz: 2
#
# runda: 11
# ręka gracza 1: [4, 1, 7, 6, 8, 5]
# ręka gracza 2: [3, 2]
# gracz 1 rzuca: 4
# gracz 2 rzuca: 3
# pozostała ręka gracza 1: [1, 7, 6, 8, 5]
# pozostała ręka gracza 2: [2]
# wygrywa gracz: 1
#
# runda: 12
# ręka gracza 1: [1, 7, 6, 8, 5, 4, 3]
# ręka gracza 2: [2]
# gracz 1 rzuca: 1
# gracz 2 rzuca: 2
# pozostała ręka gracza 1: [7, 6, 8, 5, 4, 3]
# pozostała ręka gracza 2: []
# wygrywa gracz: 2
#
# runda: 13
# ręka gracza 1: [7, 6, 8, 5, 4, 3]
# ręka gracza 2: [2, 1]
# gracz 1 rzuca: 7
# gracz 2 rzuca: 2
# pozostała ręka gracza 1: [6, 8, 5, 4, 3]
# pozostała ręka gracza 2: [1]
# wygrywa gracz: 1
#
# runda: 14
# ręka gracza 1: [6, 8, 5, 4, 3, 7, 2]
# ręka gracza 2: [1]
# gracz 1 rzuca: 6
# gracz 2 rzuca: 1
# pozostała ręka gracza 1: [8, 5, 4, 3, 7, 2]
# pozostała ręka gracza 2: []
# wygrywa gracz: 1
#
# rund rozgrywki: 14
# ```

# %%
def wojna(karty1, karty2):
    ''' Funkcja symuluję grę w wojnę.
        wypisuje kolejne działania uczestników
        zwraca numer rundy, na której zakończyła się gra '''
    runda = 0
    wygrany = 1
    # while True:
    while not(karty1 == [] or karty2 == []):
        runda += 1
        # print(f"runda: {runda}")
        print('runda: %d' % runda)
        print('ręka gracza 1: %s' % karty1)
        print('ręka gracza 2: %s' % karty2)
        
        k1 = karty1.pop(0)
        k2 = karty2.pop(0)
        
        print('gracz 1 rzuca: %d' % k1)
        print('gracz 2 rzuca: %d' % k2)
        
        print('pozostała ręka gracza 1: %s' % karty1)
        print('pozostała ręka gracza 2: %s' % karty2)
        
        if k1 > k2:
            wygrany = 1
            karty1.append(k1)
            karty1.append(k2)
        else:
            wygrany = 2
            karty2.append(k2)
            karty2.append(k1)
        print('wygrywa gracz: %d \n' % wygrany)
        
    return runda

print('rund rozgrywki:', wojna([1,4,6], [2,3,5]) )

print('\n---------------------------------------\n')

print('rund rozgrywki:', wojna([1,8,7,5], [2,4,3,6]) )
# Out:
# runda: 1
# ręka gracza 1: [1, 4, 6]
# ręka gracza 2: [2, 3, 5]
# gracz 1 rzuca: 1
# gracz 2 rzuca: 2
# pozostała ręka gracza 1: [4, 6]
# pozostała ręka gracza 2: [3, 5]
# wygrywa gracz: 2
#
# runda: 2
# ręka gracza 1: [4, 6]
# ręka gracza 2: [3, 5, 2, 1]
# gracz 1 rzuca: 4
# gracz 2 rzuca: 3
# pozostała ręka gracza 1: [6]
# pozostała ręka gracza 2: [5, 2, 1]
# wygrywa gracz: 1
#
# runda: 3
# ręka gracza 1: [6, 4, 3]
# ręka gracza 2: [5, 2, 1]
# gracz 1 rzuca: 6
# gracz 2 rzuca: 5
# pozostała ręka gracza 1: [4, 3]
# pozostała ręka gracza 2: [2, 1]
# wygrywa gracz: 1
#
# runda: 4
# ręka gracza 1: [4, 3, 6, 5]
# ręka gracza 2: [2, 1]
# gracz 1 rzuca: 4
# gracz 2 rzuca: 2
# pozostała ręka gracza 1: [3, 6, 5]
# pozostała ręka gracza 2: [1]
# wygrywa gracz: 1
#
# runda: 5
# ręka gracza 1: [3, 6, 5, 4, 2]
# ręka gracza 2: [1]
# gracz 1 rzuca: 3
# gracz 2 rzuca: 1
# pozostała ręka gracza 1: [6, 5, 4, 2]
# pozostała ręka gracza 2: []
# wygrywa gracz: 1
#
# rund rozgrywki: 5
#
# ...
